# %%
import pandas as pd

# %cd Z:\Project_Top2B\April_2023\Cortex_Clock\Diseased

df1 = pd.read_csv('GSE53162_Auti_Cortex_Age.csv')
df2 = pd.read_csv('GSE59457_HIV_Cortex_Age.csv')
df3 = pd.read_csv('GSE66351_AD_Cortex_Age.csv')
df4 = pd.read_csv('GSE67748_HIV_Cortex_Age.csv')
df5 = pd.read_csv('GSE67749_HIV_Cortex_Age.csv')
df6 = pd.read_csv('GSE74193_Schiz_Cortex_Age.csv')
df7 = pd.read_csv('GSE80970_AD_Cortex_Age.csv')
df8 = pd.read_csv('GSE109627_AD_Cortex_Age.csv')
# Out:
# Z:\Project_Top2B\April_2023\Cortex_Clock\Diseased

# %%
df1 = df1.transpose()
df1.columns = df1.iloc[0]
df1 = df1.iloc [1:, :]

df2 = df2.transpose()
df2.columns = df2.iloc[0]
df2 = df2.iloc [1:, :]

df3 = df3.transpose()
df3.columns = df3.iloc[0]
df3 = df3.iloc [1:, :]

df4 = df4.transpose()
df4.columns = df4.iloc[0]
df4 = df4.iloc [1:, :]

df5 = df5.transpose()
df5.columns = df5.iloc[0]
df5 = df5.iloc [1:, :]

df6 = df6.transpose()
df6.columns = df6.iloc[0]
df6 = df6.iloc [1:, :]

df7 = df7.transpose()
df7.columns = df7.iloc[0]
df7 = df7.iloc [1:, :]

df8 = df8.transpose()
df8.columns = df8.iloc[0]
df8 = df8.iloc [1:, :]

df8.head(2)
# Out:
# ID_REF      SAMPLE_1  SAMPLE_2  SAMPLE_3  SAMPLE_6  SAMPLE_7  SAMPLE_8  \
# Age               82        75        90        81        91        72
# cg00059225  0.249916  0.221825  0.228614  0.301278  0.315444  0.232762
#
# ID_REF     SAMPLE_9 SAMPLE_13 SAMPLE_14 SAMPLE_17  ... SAMPLE_149 SAMPLE_150  \
# Age              82        87        94        85  ...         94         85
# cg00059225  0.25609  0.202662  0.295352  0.191139  ...   0.309981   0.216058
#
# ID_REF     SAMPLE_151 SAMPLE_152 SAMPLE_153 SAMPLE_155 SAMPLE_157 SAMPLE_158  \
# Age                73         84         92         95         89         87
# cg00059225   0.178497    0.21948   0.171836    0.27926   0.209277   0.275138
#
# ID_REF     SAMPLE_161 SAMPLE_162
# Age                85         85
# cg00059225   0.261038   0.176056
#
# [2 rows x 91 columns]

# %%
from functools import reduce

df_list = [df1, df2, df3, df4, df5, df6, df7, df8]

df_merged = reduce(lambda left, right: pd.merge(left, right, left_index=True, right_index=True, how='inner'), df_list)
df_merged.fillna('void', inplace=True)

df_merged.to_csv('Merged_Cortex_Diseased_Trans.csv')
print(df_merged.shape)
df_merged.head(2)
# Out:
# (348, 627)
# ID_REF      GSM1283234  GSM1283236  GSM1283238  GSM1283239  GSM1283241  \
# Age          16.000000   29.000000   29.000000    2.000000     20.0000
# cg00059225    0.133594    0.178339    0.197618    0.111145      0.1657
#
# ID_REF      GSM1283244  GSM1283250  GSM1283253  GSM1283254  GSM1283255  ...  \
# Age           9.000000   22.000000    8.000000   51.000000    18.00000  ...
# cg00059225    0.125511    0.177821    0.139019    0.232952     0.14527  ...
#
# ID_REF      SAMPLE_149  SAMPLE_150  SAMPLE_151  SAMPLE_152  SAMPLE_153  \
# Age          94.000000   85.000000   73.000000    84.00000   92.000000
# cg00059225    0.309981    0.216058    0.178497     0.21948    0.171836
#
# ID_REF      SAMPLE_155  SAMPLE_157  SAMPLE_158  SAMPLE_161  SAMPLE_162
# Age           95.00000   89.000000   87.000000   85.000000   85.000000
# cg00059225     0.27926    0.209277    0.275138    0.261038    0.176056
#
# [2 rows x 627 columns]
