# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %cd Z:\Project_Top2B\April_2023\Files_Top2B\CpG_inRow
# Out:
# Z:\Project_Top2B\April_2023\Files_Top2B\CpG_inRow

# %%
df = pd.read_csv('CpG_236BorutaPy_onAll.csv')
#df = df.drop(['PATNO', 'Patient_ID'], axis=1)
print(df.shape)
df.head(2)
# Out:
# (225, 83)
#    Age  cg00302494  cg00357610  cg00400263  cg00474746  cg00502509  \
# 0   79    0.155883    0.051080    0.798995    0.287693    0.946753
# 1   84    0.155073    0.054537    0.817106    0.327370    0.976917
#
#    cg01029238  cg01039763  cg02051616  cg03066050  ...  cg24446586  \
# 0    0.063241    0.833593    0.273414    0.454972  ...    0.251952
# 1    0.056962    0.879512    0.267167    0.426717  ...    0.255411
#
#    cg24853724  cg26338030  cg26351776  cg26546105  cg26739510  cg26890189  \
# 0    0.148371    0.885714    0.551317    0.237225    0.607782    0.034842
# 1    0.148604    0.936365    0.579280    0.243777    0.686021    0.028206
#
#    cg27004760  cg27052113  cg27355141
# 0    0.836788    0.032780    0.589162
# 1    0.841328    0.026539    0.577874
#
# [2 rows x 83 columns]

# %%
corrmat = df.corr()
top_corr_feat = corrmat.index
plt.figure(figsize=(40,30))
hm = sns.heatmap(df[top_corr_feat].corr().round(2), annot=True, cmap='RdYlGn')
hm.set_xticklabels(hm.get_xticklabels(), fontsize=16, fontweight='bold')
hm.set_yticklabels(hm.get_yticklabels(), fontsize=16, fontweight='bold')
plt.savefig("tempout_pat.png")
